# %%
import pandas as pd

# Read the Excel file directly with pandas
df_full = pd.read_excel('old-data/Anil Close Connections.xlsx')

len(df_full)
# Out:
# 90

# %%
# Remove all columns after "Connected On"
if "Connected On" in df.columns:
    idx = df.columns.get_loc("Connected On")
    df = df.iloc[:, :idx+1]

# %%
df_full.to_csv("data/anil_connections.csv", index=False)
